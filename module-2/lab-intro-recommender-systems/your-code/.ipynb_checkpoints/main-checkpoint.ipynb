# %% [markdown]
# # Intro to Recommender Systems Lab
#
# Complete the exercises below to solidify your knowledge and understanding of recommender systems.
#
# For this lab, we are going to be putting together a user similarity based recommender system in a step-by-step fashion. Our data set contains customer grocery purchases, and we will use similar purchase behavior to inform our recommender system. Our recommender system will generate 5 recommendations for each customer based on the purchases they have made.

# %%
import pandas as pd
from scipy.spatial.distance import pdist, squareform

# %%
data = pd.read_csv('../data/customer_product_sales.csv')

# %%
data.head()
# Out:
#    CustomerID FirstName   LastName  SalesID  ProductID           ProductName  \
# 0       61288      Rosa   Andersen   134196        229  Bread - Hot Dog Buns
# 1       77352     Myron     Murray  6167892        229  Bread - Hot Dog Buns
# 2       40094     Susan  Stevenson  5970885        229  Bread - Hot Dog Buns
# 3       23548    Tricia    Vincent  6426954        229  Bread - Hot Dog Buns
# 4       78981     Scott      Burch   819094        229  Bread - Hot Dog Buns
#
#    Quantity
# 0        16
# 1        20
# 2        11
# 3         6
# 4        20

# %% [markdown]
# ## Step 1: Create a data frame that contains the total quantity of each product purchased by each customer.
#
# You will need to group by CustomerID and ProductName and then sum the Quantity field.

# %%
df = data.groupby(['CustomerID','ProductName']).sum()['Quantity']
df.sample(10)
# Out:
# CustomerID  ProductName
# 28751       Vinegar - Tarragon                8
# 13354       Chinese Foods - Chicken           4
# 74237       Ocean Spray - Kiwi Strawberry    19
# 81324       Chocolate - Compound Coating     21
# 3535        Anchovy Paste - 56 G Tube         1
# 12232       Mustard Prepared                  4
# 59831       Seedlings - Mix, Organic         32
# 6447        Garlic                            2
# 84349       Table Cloth 81x81 White          22
# 58246       Veal - Inside                    15
# Name: Quantity, dtype: int64

# %% [markdown]
# ## Step 2: Use the `pivot_table` method to create a product by customer matrix.
#
# The rows of the matrix should represent the products, the columns should represent the customers, and the values should be the quantities of each product purchased by each customer. You will also need to replace nulls with zeros, which you can do using the `fillna` method.

# %%
pivot = data.pivot_table(columns = 'CustomerID', index = 'ProductName',values = 'Quantity')
pivot.fillna(0,inplace = True)

# %% [markdown]
# ## Step 3: Create a customer similarity matrix using `squareform` and `pdist`. For the distance metric, choose "euclidean."

# %%
squareform(pdist( pivot.T , 'euclidean'))
# Out:
# array([[  0.        ,  10.72380529,   9.64365076, ..., 197.94948851,
#         218.8241303 , 203.79892051],
#        [ 10.72380529,   0.        ,  10.67707825, ..., 197.34994299,
#         218.62525014, 203.95342606],
#        [  9.64365076,  10.67707825,   0.        , ..., 197.32460566,
#         218.02981447, 203.80628057],
#        ...,
#        [197.94948851, 197.34994299, 197.32460566, ...,   0.        ,
#         266.9269563 , 266.9269563 ],
#        [218.8241303 , 218.62525014, 218.02981447, ..., 266.9269563 ,
#           0.        , 269.25824036],
#        [203.79892051, 203.95342606, 203.80628057, ..., 266.9269563 ,
#         269.25824036,   0.        ]])

# %% [markdown]
# ## Step 4: Check your results by generating a list of the top 5 most similar customers for a specific CustomerID.

# %%
distances = pd.DataFrame(1/(1 + squareform(pdist(pivot.T, 'euclidean'))), 
                         index=pivot.columns, columns=pivot.columns)

lst = distances[33].sort_values()[-6:-1]
list(lst.index)
# Out:
# [3305, 2503, 3531, 264, 3909]

# %% [markdown]
# ## Step 5: From the data frame you created in Step 1, select the records for the list of similar CustomerIDs you obtained in Step 4.

# %%
new_df= df.loc[list(lst.index)]
#new_lst = [df[i] for i in lst.index]
new_df
# Out:
# CustomerID  ProductName
# 264         Apricots - Halves                 1
#             Apricots Fresh                    1
#             Bacardi Breezer - Tropical        1
#             Bagel - Plain                     1
#             Banana - Leaves                   1
#                                              ..
# 3909        Wine - Charddonnay Errazuriz      2
#             Wine - Fume Blanc Fetzer          1
#             Wine - Magnotta, Merlot Sr Vqa    1
#             Wine - Toasted Head               1
#             Wine - Valpolicella Masi          1
# Name: Quantity, Length: 282, dtype: int64

# %% [markdown]
# ## Step 6: Aggregate those customer purchase records by ProductName, sum the Quantity field, and then rank them in descending order by quantity.
#
# This will give you the total number of each product purchased by the 5 most similar customers to the customer you selected in order from most purchased to least.

# %%
reco = new_df.groupby('ProductName').sum().sort_values()[::-1]
reco.rename('Reco', inplace = False)
# Out:
# ProductName
# Salsify, Organic                 4
# Wine - Charddonnay Errazuriz     3
# Wine - Ej Gallo Sierra Valley    3
# Oranges - Navel, 72              3
# Quiche Assorted                  3
#                                 ..
# Pepsi - Diet, 355 Ml             1
# Pepper - White, Ground           1
# Peas - Pigeon, Dry               1
# Pastry - Cheese Baked Scones     1
# Appetizer - Mushroom Tart        1
# Name: Reco, Length: 235, dtype: int64

# %% [markdown]
# ## Step 7: Filter the list for products that the chosen customer has not yet purchased and then recommend the top 5 products with the highest quantities that are left.
#
# - Merge the ranked products data frame with the customer product matrix on the ProductName field.
# - Filter for records where the chosen customer has not purchased the product.
# - Show the top 5 results.

# %%
comparison = pd.concat([df[33], reco], axis=1).fillna(0)
comparison.columns = ['Quantity','Recomendation']
comparison.sort_values(by = 'Recomendation', ascending =False)
comparison[comparison['Quantity']==0][:5]
# Out:
#                                Quantity  Recomendation
# Wine - Charddonnay Errazuriz        0.0            3.0
# Wine - Ej Gallo Sierra Valley       0.0            3.0
# Oranges - Navel, 72                 0.0            3.0
# Bay Leaf                            0.0            3.0
# Pecan Raisin - Tarts                0.0            3.0

# %%
list(comparison[comparison['Quantity']==0][:5].index)
# Out:
# ['Wine - Charddonnay Errazuriz',
#  'Wine - Ej Gallo Sierra Valley',
#  'Oranges - Navel, 72',
#  'Bay Leaf',
#  'Pecan Raisin - Tarts']

# %% [markdown]
# ## Step 8: Now that we have generated product recommendations for a single user, put the pieces together and iterate over a list of all CustomerIDs.
#
# - Create an empty dictionary that will hold the recommendations for all customers.
# - Create a list of unique CustomerIDs to iterate over.
# - Iterate over the customer list performing steps 4 through 7 for each and appending the results of each iteration to the dictionary you created.

# %%
def recomend_dict(distances):
    recomendations = {}
    clients = list(data.CustomerID.unique())
    for i in clients:
        lst = distances[i].sort_values()[-6:-1]
        new_df= df.loc[list(lst.index)]
        reco = new_df.groupby('ProductName').sum().sort_values()[::-1]
        reco.rename('Reco', inplace = False)

        comparison = pd.concat([df[33], reco], axis=1).fillna(0)
        comparison.columns = ['Quantity','Recomendation']
        comparison.sort_values(by = 'Recomendation', ascending =False)
        comparison[comparison['Quantity']==0][:5]

        recomendations[i] = list(comparison[comparison['Quantity']==0][:5].index)
    return recomendations

# %%
recomend_dict(distances)
# Out:
# {61288: ['Mushrooms - Black, Dried',
#   'Wine - Magnotta, Merlot Sr Vqa',
#   'Sponge Cake Mix - Chocolate',
#   'Beef - Rib Eye Aaa',
#   'Chicken - Soup Base'],
#  77352: ['Guinea Fowl',
#   'Grenadine',
#   'Oranges - Navel, 72',
#   'Ecolab - Mikroklene 4/4 L',
#   'Beets - Candy Cane, Organic'],
#  40094: ['Water - Mineral, Natural',
#   'Oregano - Dry, Rubbed',
#   'Pasta - Orecchiette',
#   'Wiberg Super Cure',
#   'Clam Nectar'],
#  23548: ['Tea - English Breakfast',
#   'Wanton Wrap',
#   'Banana Turning',
#   'Spinach - Baby',
#   'Flavouring - Orange'],
#  78981: ['Lettuce - Frisee',
#   'Longos - Chicken Wings',
#   'Pop Shoppe Cream Soda',
#   'Crush - Cream Soda',
#   'Beef - Inside Round'],
#  83106: ['Skirt - 29 Foot',
#   'Cheese - Boursin, Garlic / Herbs',
#   'Garlic - Peeled',
#   'Soup - Campbells Tomato Ravioli',
#   'Beef - Rib Eye Aaa'],
#  11253: ['Smirnoff Green Apple Twist',
#   'Lettuce - Treviso',
#   'Tomatoes Tear Drop',
# ...

# %% [markdown]
# ##  Step 9: Store the results in a Pandas data frame. The data frame should a column for Customer ID and then a column for each of the 5 product recommendations for each customer.

# %%
pd.DataFrame.from_dict(recomendations)
# Out:
#                             61288                        77352  \
# 0        Mushrooms - Black, Dried                  Guinea Fowl
# 1  Wine - Magnotta, Merlot Sr Vqa                    Grenadine
# 2     Sponge Cake Mix - Chocolate          Oranges - Navel, 72
# 3              Beef - Rib Eye Aaa    Ecolab - Mikroklene 4/4 L
# 4             Chicken - Soup Base  Beets - Candy Cane, Organic
#
#                       40094                    23548                   78981  \
# 0  Water - Mineral, Natural  Tea - English Breakfast        Lettuce - Frisee
# 1     Oregano - Dry, Rubbed              Wanton Wrap  Longos - Chicken Wings
# 2       Pasta - Orecchiette           Banana Turning   Pop Shoppe Cream Soda
# 3         Wiberg Super Cure           Spinach - Baby      Crush - Cream Soda
# 4               Clam Nectar      Flavouring - Orange     Beef - Inside Round
#
#                               83106                       11253  \
# ...

# %% [markdown]
# ## Step 10: Change the distance metric used in Step 3 to something other than euclidean (correlation, cityblock, consine, jaccard, etc.). Regenerate the recommendations for all customers and note the differences.

# %%
distances = pd.DataFrame(1/(1 + squareform(pdist(pivot.T, 'jaccard'))), 
                         index=pivot.columns, columns=pivot.columns)
pd.DataFrame.from_dict(recomend_dict(distances))
# Out:
#                            61288                          77352  \
# 0    Sponge Cake Mix - Chocolate      Beer - Sleemans Cream Ale
# 1                  Yoghurt Tubes             Pasta - Angel Hair
# 2  Soup - Campbells, Beef Barley              Beef - Short Loin
# 3    Cheese - Brie, Triple Creme    Mayonnaise - Individual Pkg
# 4      Juice - Cranberry, 341 Ml  Wine - Blue Nun Qualitatswein
#
#                        40094                          23548  \
# 0         Pasta - Angel Hair  Wine - Hardys Bankside Shiraz
# 1   Snapple - Iced Tea Peach        Table Cloth 81x81 White
# 2             Rosemary - Dry    Wine - Cahors Ac 2000, Clos
# 3  Juice - Cranberry, 341 Ml     Lemonade - Natural, 591 Ml
# 4     Artichokes - Jerusalem             Cookies Cereal Nut
#
#                              78981                  83106  \
# 0        Appetizer - Sausage Rolls   Salmon - Sockeye Raw
# 1  Muffin Batt - Blueberry Passion       Mustard Prepared
# ...

# %%
#in our case we got completely different recomendations when we 
#changed the metric.
