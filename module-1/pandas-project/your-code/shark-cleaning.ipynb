# %%
import pandas as pd
import re
import numpy as np

# %%
df = pd.read_csv('attacks.csv', encoding='latin-1', index_col= False)
#Teniamos un error al leer el tipo de datos

# %%
df.dtypes
# Out:
# Case Number                object
# Date                       object
# Year                      float64
# Type                       object
# Country                    object
# Area                       object
# Location                   object
# Activity                   object
# Name                       object
# Sex                        object
# Age                        object
# Injury                     object
# Fatal (Y/N)                object
# Time                       object
# Species                    object
# Investigator or Source     object
# pdf                        object
# href formula               object
# href                       object
# Case Number.1              object
# Case Number.2              object
# original order            float64
# Unnamed: 22                object
# Unnamed: 23                object
# dtype: object

# %%
df.head()
# Out:
#   Case Number         Date    Year        Type    Country             Area  \
# 0  2018.06.25  25-Jun-2018  2018.0     Boating        USA       California
# 1  2018.06.18  18-Jun-2018  2018.0  Unprovoked        USA          Georgia
# 2  2018.06.09  09-Jun-2018  2018.0     Invalid        USA           Hawaii
# 3  2018.06.08  08-Jun-2018  2018.0  Unprovoked  AUSTRALIA  New South Wales
# 4  2018.06.04  04-Jun-2018  2018.0    Provoked     MEXICO           Colima
#
#                          Location     Activity              Name Sex   ...  \
# 0     Oceanside, San Diego County     Paddling       Julie Wolfe    F  ...
# 1  St. Simon Island, Glynn County     Standing  AdysonÂ McNeely     F  ...
# 2                    Habush, Oahu      Surfing       John Denges    M  ...
# 3              Arrawarra Headland      Surfing              male    M  ...
# 4                        La Ticla  Free diving    Gustavo Ramos     M  ...
#
#           Species           Investigator or Source                       pdf  \
# 0      White shark                R. Collier, GSAF      2018.06.25-Wolfe.pdf
# 1              NaN  K.McMurray, TrackingSharks.com    2018.06.18-McNeely.pdf
# 2              NaN  K.McMurray, TrackingSharks.com     2018.06.09-Denges.pdf
# 3        2 m shark                  B. Myatt, GSAF  2018.06.08-Arrawarra.pdf
# 4  Tiger shark, 3m                       A .Kipper      2018.06.04-Ramos.pdf
#
#                                         href formula  \
# 0  http://sharkattackfile.net/spreadsheets/pdf_di...
# 1  http://sharkattackfile.net/spreadsheets/pdf_di...
# 2  http://sharkattackfile.net/spreadsheets/pdf_di...
# 3  http://sharkattackfile.net/spreadsheets/pdf_di...
# 4  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                 href Case Number.1  \
# 0  http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.25
# 1  http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.18
# 2  http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.09
# 3  http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.08
# 4  http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.04
#
#   Case Number.2 original order Unnamed: 22 Unnamed: 23
# 0    2018.06.25         6303.0         NaN         NaN
# 1    2018.06.18         6302.0         NaN         NaN
# 2    2018.06.09         6301.0         NaN         NaN
# 3    2018.06.08         6300.0         NaN         NaN
# 4    2018.06.04         6299.0         NaN         NaN
#
# [5 rows x 24 columns]

# %%
### We will eliminate all the rows  and columns that are empty (near, empty)at the end that are empty
df = df[df.isnull().sum(axis=1) < 10]
df.dropna(thresh = 1000, axis=1, inplace=True)

# %%
#We will check for original order and see if we can use that for indexing our data. 
#We are only missing some value 1
df = df.set_index(df['original order'].astype(int).apply(lambda x: x-1))
df.drop('original order', axis=1, inplace=True)

# %%
df.index.name = None

# %%
#let's check if case number, case number.1 and case number.2 are the same
cases = df[['Case Number','Case Number.1','Case Number.2']].copy()

cases['diff']= np.where((df['Case Number'] == df['Case Number.1'])& (df['Case Number'] == df['Case Number.2']) & (df['Case Number.1'] == df['Case Number.2']), 'no change', 'diff')
cases.loc[cases['diff'] == 'diff']
# Out:
#        Case Number Case Number.1 Case Number.2  diff
# 6268    2018.04.03    2018.04.02    2018.04.03  diff
# 6185  2017.07.20.a  2017/07.20.a  2017.07.20.a  diff
# 6158    2017.05.06    2017.06.06    2017.05.06  diff
# 6085    2016.09.15    2016.09.16    2016.09.15  diff
# 5988  2016.01.24.b  2015.01.24.b  2016.01.24.b  diff
# 5968    2015.12.23    2015.11.07    2015.12.23  diff
# 5963  2015.10.28.a    2015.10.28  2015.10.28.a  diff
# 5912    2015.07-10    2015.07.10    2015.07.10  diff
# 5742    2014.05.04    2013.05.04    2014.05.04  diff
# 2780    1967.07.05    1967/07.05    1967.07.05  diff
# 2507  1962,08.30.b  1962.08.30.b  1962,08.30.b  diff
# 2422  1961.09.02.R  1961.09,06.R  1961.09.02.R  diff
# 1899    1952.08.05    1952.08.04    1952.08.05  diff
# 1877  1851.12.15.R  1951.12.15.R  1851.12.15.R  diff
# 1353  1934.01.08.R  1934.02.08.R  1934.02.08.R  diff
# 1027  1900.00.00.R  1919.00.00.R  1900.00.00.R  diff
# 944   1913.07.10.R  1913.17.10.R  1913.07.10.R  diff
# 916   1911.07.31.R  1911.07.31.T  1911.07.31.R  diff
# 814            NaN  1905.09.06.R  1905.09.06.R  diff
# 525   1884.04.38.R  1884.04.28.R  1884.04.38.R  diff
# 419   1876.06.18.R  1874.06.18.R  1876.06.18.R  diff
# 358        1864.05    1864.05.00    1864.05.00  diff
# 293     1853,94.29    1853.04.29    1853,94.29  diff

# %%
#Change values, 2/3 or best fit
df.loc[5912,'Case Number'] = df.loc[5912,'Case Number.1']
df.loc[2507,'Case Number'] = df.loc[2507,'Case Number.1']
df.loc[1877,'Case Number'] = df.loc[1877,'Case Number.1']
df.loc[1353,'Case Number'] = df.loc[1353,'Case Number.1']
df.loc[1027,'Case Number'] = df.loc[1027,'Case Number.1']
df.loc[814,'Case Number'] = df.loc[814,'Case Number.1']
df.loc[525,'Case Number'] = df.loc[525,'Case Number.1']
df.loc[358,'Case Number'] = df.loc[358,'Case Number.1']
df.loc[293,'Case Number'] = df.loc[293,'Case Number.1']

# %%
#Ahora podemos eliminar las columnas Case Number.1 y Case Number.2
df.drop(['Case Number.1', 'Case Number.2'], axis=1, inplace=True)
#Clean case number (..,-'/
df['Case Number']= df['Case Number'].str.replace('\.\.|\.|\'|\/|\s|\-','.', regex = True)
df.head()
# Out:
#      Case Number         Date    Year        Type    Country             Area  \
# 6302  2018.06.25  25-Jun-2018  2018.0     Boating        USA       California
# 6301  2018.06.18  18-Jun-2018  2018.0  Unprovoked        USA          Georgia
# 6300  2018.06.09  09-Jun-2018  2018.0     Invalid        USA           Hawaii
# 6299  2018.06.08  08-Jun-2018  2018.0  Unprovoked  AUSTRALIA  New South Wales
# 6298  2018.06.04  04-Jun-2018  2018.0    Provoked     MEXICO           Colima
#
#                             Location     Activity              Name Sex   Age  \
# 6302     Oceanside, San Diego County     Paddling       Julie Wolfe    F   57
# 6301  St. Simon Island, Glynn County     Standing  AdysonÂ McNeely     F   11
# 6300                    Habush, Oahu      Surfing       John Denges    M   48
# 6299              Arrawarra Headland      Surfing              male    M  NaN
# 6298                        La Ticla  Free diving    Gustavo Ramos     M  NaN
#
#                                                  Injury Fatal (Y/N)  \
# 6302  No injury to occupant, outrigger canoe and pad...           N
# 6301                         Minor injury to left thigh           N
# 6300       Injury to left lower leg from surfboard skeg           N
# 6299                          Minor injury to lower leg           N
# 6298  Lacerations to leg & hand shark PROVOKED INCIDENT           N
#
#                Time         Species           Investigator or Source  \
# 6302          18h00      White shark                R. Collier, GSAF
# 6301  14h00  -15h00              NaN  K.McMurray, TrackingSharks.com
# 6300          07h45              NaN  K.McMurray, TrackingSharks.com
# 6299            NaN        2 m shark                  B. Myatt, GSAF
# 6298            NaN  Tiger shark, 3m                       A .Kipper
#
#                            pdf  \
# 6302      2018.06.25-Wolfe.pdf
# 6301    2018.06.18-McNeely.pdf
# 6300     2018.06.09-Denges.pdf
# 6299  2018.06.08-Arrawarra.pdf
# 6298      2018.06.04-Ramos.pdf
#
#                                            href formula  \
# 6302  http://sharkattackfile.net/spreadsheets/pdf_di...
# 6301  http://sharkattackfile.net/spreadsheets/pdf_di...
# 6300  http://sharkattackfile.net/spreadsheets/pdf_di...
# 6299  http://sharkattackfile.net/spreadsheets/pdf_di...
# 6298  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                    href
# 6302  http://sharkattackfile.net/spreadsheets/pdf_di...
# 6301  http://sharkattackfile.net/spreadsheets/pdf_di...
# 6300  http://sharkattackfile.net/spreadsheets/pdf_di...
# 6299  http://sharkattackfile.net/spreadsheets/pdf_di...
# 6298  http://sharkattackfile.net/spreadsheets/pdf_di...

# %%
#Let's see if we can get to separate date into three columns either from case number or the date value

# %%
#We will check if we can reduce href and href formula to only one column
refs = df[['href','href formula']].copy()

refs['diff']= np.where(df['href'] == df['href formula'], 'no change', 'diff')
refs.loc[refs['diff'] == 'diff']
# Out:
#                                                    href  \
# 6252  http://sharkattackfile.net/spreadsheets/pdf_di...
# 6206  http://sharkattackfile.net/spreadsheets/pdf_di...
# 6171  http://sharkattackfile.net/spreadsheets/pdf_di...
# 6169  http://sharkattackfile.net/spreadsheets/pdf_di...
# 6161  http://sharkattackfile.net/spreadsheets/pdf_di...
# 6134  http://sharkattackfile.net/spreadsheets/pdf_di...
# 6068  http://sharkattackfile.net/spreadsheets/pdf_di...
# 6061  http://sharkattackfile.net/spreadsheets/pdf_di...
# 6026  http://sharkattackfile.net/spreadsheets/pdf_di...
# 5978  http://sharkattackfile.net/spreadsheets/pdf_di...
# 5970  http://sharkattackfile.net/spreadsheets/pdf_di...
# 5950  http://sharkattackfile.net/spreadsheets/pdf_di...
# 5901  http://sharkattackfile.net/spreadsheets/pdf_di...
# 5849  http://sharkattackfile.net/spreadsheets/pdf_di...
# 5818  http://sharkattackfile.net/spreadsheets/pdf_di...
# 5817  http://sharkattackfile.net/spreadsheets/pdf_di...
# 5816  http://sharkattackfile.net/spreadsheets/pdf_di...
# 5809  http://sharkattackfile.net/spreadsheets/pdf_di...
# 5808  http://sharkattackfile.net/spreadsheets/pdf_di...
# 5787  http://sharkattackfile.net/spreadsheets/pdf_di...
# 5775  http://sharkattackfile.net/spreadsheets/pdf_di...
# 5757  http://sharkattackfile.net/spreadsheets/pdf_di...
# 5733  http://sharkattackfile.net/spreadsheets/pdf_di...
# 5719  http://sharkattackfile.net/spreadsheets/pdf_di...
# 5718  http://sharkattackfile.net/spreadsheets/pdf_di...
# 5717  http://sharkattackfile.net/spreadsheets/pdf_di...
# 5716  http://sharkattackfile.net/spreadsheets/pdf_di...
# 5715                  pdf_directory2014.01.04-Riano.pdf
# 5714  http://sharkattackfile.net/spreadsheets/pdf_di...
# 5702  http://sharkattackfile.net/spreadsheets/pdf_di...
# 5701  http://sharkattackfile.net/spreadsheets/pdf_di...
# 5700  http://sharkattackfile.net/spreadsheets/pdf_di...
# 5699  http://sharkattackfile.net/spreadsheets/pdf_di...
# 5698  http://sharkattackfile.net/spreadsheets/pdf_di...
# 5697  http://sharkattackfile.net/spreadsheets/pdf_di...
# 5696  http://sharkattackfile.net/spreadsheets/pdf_di...
# 5695  http://sharkattackfile.net/spreadsheets/pdf_di...
# 5631  http://sharkattackfile.net/spreadsheets/pdf_di...
# 5630  http://sharkattackfile.net/spreadsheets/pdf_di...
# 5256  http://sharkattackfile.net/spreadsheets/pdf_di...
# 4861  http://sharkattackfile.net/spreadsheets/pdf_di...
# 4860  http://sharkattackfile.net/spreadsheets/pdf_di...
# 3600  http://sharkattackfile.net/spreadsheets/pdf_di...
# 3058  http://sharkattackfile.net/spreadsheets/pdf_di...
# 3057  http://sharkattackfile.net/spreadsheets/pdf_di...
# 2527  http://sharkattackfile.net/spreadsheets/pdf_di...
# 2473  http://sharkattackfile.net/spreadsheets/pdf_di...
# 2159  http://sharkattackfile.net/spreadsheets/pdf_di...
# 2148  http://sharkattackfile.net/spreadsheets/pdf_di...
# 1681  http://sharkattackfile.net/spreadsheets/pdf_di...
# 1430  http://sharkattackfile.net/spreadsheets/pdf_di...
# 1404  http://sharkattackfile.net/spreadsheets/pdf_di...
# 1353  http://sharkattackfile.net/spreadsheets/pdf_di...
# 1057  http://sharkattackfile.net/spreadsheets/pdf_di...
# 953   http://sharkattackfile.net/spreadsheets/pdf_di...
# 746   http://sharkattackfile.net/spreadsheets/pdf_di...
# 601   http://sharkattackfile.net/spreadsheets/pdf_di...
# 192   http://sharkattackfile.net/spreadsheets/pdf_di...
# 136   http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                            href formula  diff
# 6252  http://sharkattackfile.net/spreadsheets/pdf_di...  diff
# 6206  http://sharkattackfile.net/spreadsheets/pdf_di...  diff
# 6171  http://sharkattackfile.net/spreadsheets/pdf_di...  diff
# 6169  http://sharkattackfile.net/spreadsheets/pdf_di...  diff
# 6161  http://sharkattackfile.net/spreadsheets/pdf_di...  diff
# 6134  http://sharkattackfile.net/spreadsheets/pdf_di...  diff
# 6068  http://sharkattackfile.net/spreadsheets/pdf_di...  diff
# 6061  http://sharkattackfile.net/spreadsheets/pdf_di...  diff
# 6026  http://sharkattackfile.net/spreadsheets/pdf_di...  diff
# 5978  http://sharkattackfile.net/spreadsheets/pdf_di...  diff
# 5970  http://sharkattackfile.net/spreadsheets/pdf_di...  diff
# 5950  http://sharkattackfile.net/spreadsheets/pdf_di...  diff
# 5901  http://sharkattackfile.net/spreadsheets/pdf_di...  diff
# 5849  http://sharkattackfile.net/spreadsheets/pdf_di...  diff
# 5818  http://sharkattackfile.net/spreadsheets/pdf_di...  diff
# 5817  http://sharkattackfile.net/spreadsheets/pdf_di...  diff
# 5816  http://sharkattackfile.net/spreadsheets/pdf_di...  diff
# 5809  http://sharkattackfile.net/spreadsheets/pdf_di...  diff
# 5808  http://sharkattackfile.net/spreadsheets/pdf_di...  diff
# 5787  http://sharkattackfile.net/spreadsheets/pdf_di...  diff
# 5775  http://sharkattackfile.net/spreadsheets/pdf_di...  diff
# 5757  http://sharkattackfile.net/spreadsheets/pdf_di...  diff
# 5733  http://sharkattackfile.net/spreadsheets/pdf_di...  diff
# 5719  http://sharkattackfile.net/spreadsheets/pdf_di...  diff
# 5718  http://sharkattackfile.net/spreadsheets/pdf_di...  diff
# 5717  http://sharkattackfile.net/spreadsheets/pdf_di...  diff
# 5716  http://sharkattackfile.net/spreadsheets/pdf_di...  diff
# 5715  http://sharkattackfile.net/spreadsheets/pdf_di...  diff
# 5714  http://sharkattackfile.net/spreadsheets/pdf_di...  diff
# 5702  http://sharkattackfile.net/spreadsheets/pdf_di...  diff
# 5701  http://sharkattackfile.net/spreadsheets/pdf_di...  diff
# 5700  http://sharkattackfile.net/spreadsheets/pdf_di...  diff
# 5699  http://sharkattackfile.net/spreadsheets/pdf_di...  diff
# 5698  http://sharkattackfile.net/spreadsheets/pdf_di...  diff
# 5697  http://sharkattackfile.net/spreadsheets/pdf_di...  diff
# 5696  http://sharkattackfile.net/spreadsheets/pdf_di...  diff
# 5695  http://sharkattackfile.net/spreadsheets/pdf_di...  diff
# 5631                 pdf-directory/2013.05.27.b-Ena.pdf  diff
# 5630  http://sharkattackfile.net/spreadsheets/pdf_di...  diff
# 5256  http://sharkattackfile.net/spreadsheets/pdf_di...  diff
# 4861  http://sharkattackfile.net/spreadsheets/pdf_di...  diff
# 4860  http://sharkattackfile.net/spreadsheets/pdf_di...  diff
# 3600  http://sharkattackfile.net/spreadsheets/pdf_di...  diff
# 3058                                                NaN  diff
# 3057                                            #VALUE!  diff
# 2527  http://sharkattackfile.net/spreadsheets/pdf_di...  diff
# 2473  http://sharkattackfile.net/spreadsheets/pdf_di...  diff
# 2159  http://sharkattackfile.net/spreadsheets/pdf_di...  diff
# 2148  http://sharkattackfile.net/spreadsheets/pdf_di...  diff
# 1681  http://sharkattackfile.net/spreadsheets/pdf_di...  diff
# 1430  http://sharkattackfile.net/spreadsheets/pdf_di...  diff
# 1404  http://sharkattackfile.net/spreadsheets/pdf_di...  diff
# 1353  http://sharkattackfile.net/spreadsheets/pdf_di...  diff
# 1057  http://sharkattackfile.net/spreadsheets/pdf_di...  diff
# 953   http://sharkattackfile.net/spreadsheets/pdf_di...  diff
# 746   http://sharkattackfile.net/spreadsheets/pdf_di...  diff
# 601   http://sharkattackfile.net/spreadsheets/pdf_di...  diff
# 192   http://sharkattackfile.net/spreadsheets/pdf_di...  diff
# 136   http://sharkattackfile.net/spreadsheets/pdf_di...  diff

# %%
refs['href'] = refs['href'].str.replace(".*(?=http://)", "")
refs['href formula'] = refs['href formula'].str.replace(".*(?=http://)", "")

# %%
#this fixes the double Url that we had in some entries
df['href'] = df['href'].str.replace(".*(?=http://)", "")
df['href formula'] = df['href formula'].str.replace(".*(?=http://)", "")

# %%
refs['diff']= np.where(df['href'] == df['href formula'], 'no change', 'diff')
refs.loc[refs['diff'] == 'diff']
#But we still have a lot of differente entries
# Out:
#                                                    href  \
# 6061  http://sharkattackfile.net/spreadsheets/pdf_di...
# 5950  http://sharkattackfile.net/spreadsheets/pdf_di...
# 5901  http://sharkattackfile.net/spreadsheets/pdf_di...
# 5817  http://sharkattackfile.net/spreadsheets/pdf_di...
# 5816  http://sharkattackfile.net/spreadsheets/pdf_di...
# 5809  http://sharkattackfile.net/spreadsheets/pdf_di...
# 5808  http://sharkattackfile.net/spreadsheets/pdf_di...
# 5787  http://sharkattackfile.net/spreadsheets/pdf_di...
# 5757  http://sharkattackfile.net/spreadsheets/pdf_di...
# 5719  http://sharkattackfile.net/spreadsheets/pdf_di...
# 5718  http://sharkattackfile.net/spreadsheets/pdf_di...
# 5717  http://sharkattackfile.net/spreadsheets/pdf_di...
# 5716  http://sharkattackfile.net/spreadsheets/pdf_di...
# 5715                  pdf_directory2014.01.04-Riano.pdf
# 5702  http://sharkattackfile.net/spreadsheets/pdf_di...
# 5701  http://sharkattackfile.net/spreadsheets/pdf_di...
# 5700  http://sharkattackfile.net/spreadsheets/pdf_di...
# 5699  http://sharkattackfile.net/spreadsheets/pdf_di...
# 5698  http://sharkattackfile.net/spreadsheets/pdf_di...
# 5697  http://sharkattackfile.net/spreadsheets/pdf_di...
# 5696  http://sharkattackfile.net/spreadsheets/pdf_di...
# 5695  http://sharkattackfile.net/spreadsheets/pdf_di...
# 5631  http://sharkattackfile.net/spreadsheets/pdf_di...
# 5630  http://sharkattackfile.net/spreadsheets/pdf_di...
# 5256  http://sharkattackfile.net/spreadsheets/pdf_di...
# 4861  http://sharkattackfile.net/spreadsheets/pdf_di...
# 4860  http://sharkattackfile.net/spreadsheets/pdf_di...
# 3600  http://sharkattackfile.net/spreadsheets/pdf_di...
# 3058  http://sharkattackfile.net/spreadsheets/pdf_di...
# 3057  http://sharkattackfile.net/spreadsheets/pdf_di...
# 2159  http://sharkattackfile.net/spreadsheets/pdf_di...
# 2148  http://sharkattackfile.net/spreadsheets/pdf_di...
# 1681  http://sharkattackfile.net/spreadsheets/pdf_di...
# 1404  http://sharkattackfile.net/spreadsheets/pdf_di...
# 192   http://sharkattackfile.net/spreadsheets/pdf_di...
# 136   http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                            href formula  diff
# 6061  http://sharkattackfile.net/spreadsheets/pdf_di...  diff
# 5950  http://sharkattackfile.net/spreadsheets/pdf_di...  diff
# 5901  http://sharkattackfile.net/spreadsheets/pdf_di...  diff
# 5817  http://sharkattackfile.net/spreadsheets/pdf_di...  diff
# 5816  http://sharkattackfile.net/spreadsheets/pdf_di...  diff
# 5809  http://sharkattackfile.net/spreadsheets/pdf_di...  diff
# 5808  http://sharkattackfile.net/spreadsheets/pdf_di...  diff
# 5787  http://sharkattackfile.net/spreadsheets/pdf_di...  diff
# 5757  http://sharkattackfile.net/spreadsheets/pdf_di...  diff
# 5719  http://sharkattackfile.net/spreadsheets/pdf_di...  diff
# 5718  http://sharkattackfile.net/spreadsheets/pdf_di...  diff
# 5717  http://sharkattackfile.net/spreadsheets/pdf_di...  diff
# 5716  http://sharkattackfile.net/spreadsheets/pdf_di...  diff
# 5715  http://sharkattackfile.net/spreadsheets/pdf_di...  diff
# 5702  http://sharkattackfile.net/spreadsheets/pdf_di...  diff
# 5701  http://sharkattackfile.net/spreadsheets/pdf_di...  diff
# 5700  http://sharkattackfile.net/spreadsheets/pdf_di...  diff
# 5699  http://sharkattackfile.net/spreadsheets/pdf_di...  diff
# 5698  http://sharkattackfile.net/spreadsheets/pdf_di...  diff
# 5697  http://sharkattackfile.net/spreadsheets/pdf_di...  diff
# 5696  http://sharkattackfile.net/spreadsheets/pdf_di...  diff
# 5695  http://sharkattackfile.net/spreadsheets/pdf_di...  diff
# 5631                 pdf-directory/2013.05.27.b-Ena.pdf  diff
# 5630  http://sharkattackfile.net/spreadsheets/pdf_di...  diff
# 5256  http://sharkattackfile.net/spreadsheets/pdf_di...  diff
# 4861  http://sharkattackfile.net/spreadsheets/pdf_di...  diff
# 4860  http://sharkattackfile.net/spreadsheets/pdf_di...  diff
# 3600  http://sharkattackfile.net/spreadsheets/pdf_di...  diff
# 3058                                                NaN  diff
# 3057                                            #VALUE!  diff
# 2159  http://sharkattackfile.net/spreadsheets/pdf_di...  diff
# 2148  http://sharkattackfile.net/spreadsheets/pdf_di...  diff
# 1681  http://sharkattackfile.net/spreadsheets/pdf_di...  diff
# 1404  http://sharkattackfile.net/spreadsheets/pdf_di...  diff
# 192   http://sharkattackfile.net/spreadsheets/pdf_di...  diff
# 136   http://sharkattackfile.net/spreadsheets/pdf_di...  diff

# %%
#remplazar valores correctors de la otra columna
df.loc[5631,'href formula'] = df.loc[5631,'href']
df.loc[3058,'href formula'] = df.loc[3058,'href']
df.loc[3057,'href formula'] = df.loc[3057,'href']

# %%
#####We could take just the filename, and then add de case number to the url.
## so we will try to have just  the file name.pdf
refs['href'] = df['href'].str.extract("([^-]+.pdf$)")
refs['href formula'] = df['href formula'].str.extract("([^-]+.pdf$)")

# %%
####Let's clean Date so then we can clean Case number
df['Date'] = df['Date'].str.replace("Reported", "")

# %%
df['Date'] = pd.to_datetime( df['Date'], format='%d-%b-%Y', errors = 'ignore')
df['Date'] = pd.to_datetime( df['Date'], format='%b-%Y', errors = 'ignore')

# %%
##R solo aparece cuándo es reportado, pero existen casos R1 y R2 y hay que cabiarlos al formato a,b,c,..

#case['Case Number'] = df['Case Number'].str.replace("R1", "a")
#case['Case Number'] = df['Case Number'].str.replace("R2", "b")
#case['Case Number'] = df['Case Number'].str.replace("R3", "c")
#case['Case Number'] = df['Case Number'].str.replace('/' , ".")
#case['Case Number'] = df['Case Number'].str.replace("-", ".")
                                                    
#case[case['Case Number'].str.contains("R")]

# %%
######looking at the file name format, it has the case number and the victim/place
pdf = df.copy()
pdf['file'] = pdf['pdf'].str.extract("([^-]+.pdf$)")
pdf['case'] = pdf['pdf'].str.replace("(-[^-]+.pdf$)", "")
refs['files']=pdf['file']

# %%
###Comparing the end of the reference with the name of the pdf file
refs['diff']= np.where(refs['href'] == pdf['file'], 'no change', 'change')
refs.loc[refs['diff'] == 'change']
# Out:
#                                                    href  \
# 6272                                                NaN
# 6248  http://sharkattackfile.net/spreadsheets/pdf_di...
# 6196  http://sharkattackfile.net/spreadsheets/pdf_di...
# 6147  http://sharkattackfile.net/spreadsheets/pdf_di...
# 6129                                                NaN
# 5926                                                NaN
# 5904                                                NaN
# 5888                                                NaN
# 5817                                                NaN
# 5816                                          Bandy.pdf
# 5809                                     Vandenberg.pdf
# 5808                                     Vandenberg.pdf
# 5737                                                NaN
# 5728                                                NaN
# 5721                                                NaN
# 5719                                          Grant.pdf
# 5718                                          Grant.pdf
# 5717                                          Grant.pdf
# 5716                                          Grant.pdf
# 5715                                          Riano.pdf
# 5702                                                NaN
# 5701                                                NaN
# 5700                                                NaN
# 5699                                                NaN
# 5698                                                NaN
# 5697                                                NaN
# 5696                                                NaN
# 5695                                                NaN
# 5654                                                NaN
# 5256                                           Ward.pdf
# 5075                                                NaN
# 4861                                      IsaulCoba.pdf
# 4860                                     incomplete.pdf
# 3601                                                NaN
# 3363                                                NaN
# 2507  http://sharkattackfile.net/spreadsheets/pdf_di...
# 2148                                       Waterman.pdf
# 2089                                                NaN
# 1681                               USS Indianapolis.pdf
# 1594                                                NaN
# 1404                                                NaN
# 1136  http://sharkattackfile.net/spreadsheets/pdf_di...
# 1115  http://sharkattackfile.net/spreadsheets/pdf_di...
# 968   http://sharkattackfile.net/spreadsheets/pdf_di...
# 966   http://sharkattackfile.net/spreadsheets/pdf_di...
# 807                                                 NaN
# 733                                                 NaN
# 715   http://sharkattackfile.net/spreadsheets/pdf_di...
# 578                                                 NaN
# 372                                                 NaN
# 358   http://sharkattackfile.net/spreadsheets/pdf_di...
# 166                                                 NaN
#
#                                            href formula    diff  \
# 6272                                                NaN  change
# 6248  http://sharkattackfile.net/spreadsheets/pdf_di...  change
# 6196  http://sharkattackfile.net/spreadsheets/pdf_di...  change
# 6147  http://sharkattackfile.net/spreadsheets/pdf_di...  change
# 6129                                                NaN  change
# 5926                                                NaN  change
# 5904                                                NaN  change
# 5888                                                NaN  change
# 5817                                       Roberson.pdf  change
# 5816                                        Olsson, pdf  change
# 5809                                        Kayaks2.pdf  change
# 5808                                        Kayaks1.pdf  change
# 5737                                                NaN  change
# 5728                                                NaN  change
# 5721                                                NaN  change
# 5719                                         Torres.pdf  change
# 5718                                    PorpoiseBay.pdf  change
# 5717                                                NaN  change
# 5716                                                NaN  change
# 5715                                         Rianto.pdf  change
# 5702                                       Gardiner.pdf  change
# 5701                                           Daly.pdf  change
# 5700                                        Bahamas.pdf  change
# 5699                                          Gates.pdf  change
# 5698                                         Melian.pdf  change
# 5697                               ChristianBrandon.pdf  change
# 5696                                        Simmons.pdf  change
# 5695                                         Tanguy.pdf  change
# 5654                                                NaN  change
# 5256                                                NaN  change
# 5075                                                NaN  change
# 4861                                           Melo.pdf  change
# 4860                                           Coba.pdf  change
# 3601                                                NaN  change
# 3363                                                NaN  change
# 2507  http://sharkattackfile.net/spreadsheets/pdf_di...  change
# 2148                                       Waterman.pdf  change
# 2089                                                NaN  change
# 1681                               USS Indianapolis.pdf  change
# 1594                                                NaN  change
# 1404                                     Atherfield.pdf  change
# 1136  http://sharkattackfile.net/spreadsheets/pdf_di...  change
# 1115  http://sharkattackfile.net/spreadsheets/pdf_di...  change
# 968   http://sharkattackfile.net/spreadsheets/pdf_di...  change
# 966   http://sharkattackfile.net/spreadsheets/pdf_di...  change
# 807                                                 NaN  change
# 733                                                 NaN  change
# 715   http://sharkattackfile.net/spreadsheets/pdf_di...  change
# 578                                                 NaN  change
# 372                                                 NaN  change
# 358   http://sharkattackfile.net/spreadsheets/pdf_di...  change
# 166                                                 NaN  change
#
#                                      files
# 6272                                   NaN
# 6248                  2017.12.30.Jones.pdf
# 6196                        2017.07.31.pdf
# 6147              2017.04.17.a Brouwer.pdf
# 6129                                   NaN
# 5926                                   NaN
# 5904                                   NaN
# 5888                                   NaN
# 5817                          Roberson.pdf
# 5816                           Olsson, pdf
# 5809                           Kayaks2.pdf
# 5808                           Kayaks1.pdf
# 5737                                   NaN
# 5728                                   NaN
# 5721                                   NaN
# 5719                            Torres.pdf
# 5718                       PorpoiseBay.pdf
# 5717                                   NaN
# 5716                                   NaN
# 5715                            Rianto.pdf
# 5702                          Gardiner.pdf
# 5701                              Daly.pdf
# 5700                           Bahamas.pdf
# 5699                             Gates.pdf
# 5698                            Melian.pdf
# 5697                  ChristianBrandon.pdf
# 5696                           Simmons.pdf
# 5695                            Tanguy.pdf
# 5654                                   NaN
# 5256                                   NaN
# 5075                                   NaN
# 4861                              Melo.pdf
# 4860                              Coba.pdf
# 3601                                   NaN
# 3363                                   NaN
# 2507                      1962.08.30.b-pdf
# 2148                          Waterman.pdf
# 2089                                   NaN
# 1681                  USS Indianapolis.pdf
# 1594                                   NaN
# 1404                        Atherfield.pdf
# 1136  1925.06.15 Princess Royal Harbor.pdf
# 1115               1924.03.24.Sisargas.pdf
# 968                       1914.07.15.R.pdf
# 966                         1914.07.07.pdf
# 807                                    NaN
# 733                                    NaN
# 715               1898.09.19.a.R.Sully.pdf
# 578                                    NaN
# 372                                    NaN
# 358               1864.05.00.Mauritius.pdf
# 166                                    NaN

# %%
###it looks like 'href formula' is more like 'pdf' than 'href'
df.drop('href', axis=1, inplace=True)
refs.drop('href', axis=1, inplace=True)
refs['diff']= np.where(refs['href formula'] == refs['files'], 'no change', 'change')

# %%
refs.loc[refs['diff'] == 'change']
# Out:
#                                            href formula    diff  \
# 6272                                                NaN  change
# 6248  http://sharkattackfile.net/spreadsheets/pdf_di...  change
# 6196  http://sharkattackfile.net/spreadsheets/pdf_di...  change
# 6147  http://sharkattackfile.net/spreadsheets/pdf_di...  change
# 6129                                                NaN  change
# 5926                                                NaN  change
# 5904                                                NaN  change
# 5888                                                NaN  change
# 5737                                                NaN  change
# 5728                                                NaN  change
# 5721                                                NaN  change
# 5717                                                NaN  change
# 5716                                                NaN  change
# 5654                                                NaN  change
# 5256                                                NaN  change
# 5075                                                NaN  change
# 3601                                                NaN  change
# 3363                                                NaN  change
# 2507  http://sharkattackfile.net/spreadsheets/pdf_di...  change
# 2089                                                NaN  change
# 1594                                                NaN  change
# 1136  http://sharkattackfile.net/spreadsheets/pdf_di...  change
# 1115  http://sharkattackfile.net/spreadsheets/pdf_di...  change
# 968   http://sharkattackfile.net/spreadsheets/pdf_di...  change
# 966   http://sharkattackfile.net/spreadsheets/pdf_di...  change
# 807                                                 NaN  change
# 733                                                 NaN  change
# 715   http://sharkattackfile.net/spreadsheets/pdf_di...  change
# 578                                                 NaN  change
# 372                                                 NaN  change
# 358   http://sharkattackfile.net/spreadsheets/pdf_di...  change
# 166                                                 NaN  change
#
#                                      files
# 6272                                   NaN
# 6248                  2017.12.30.Jones.pdf
# 6196                        2017.07.31.pdf
# 6147              2017.04.17.a Brouwer.pdf
# 6129                                   NaN
# 5926                                   NaN
# 5904                                   NaN
# 5888                                   NaN
# 5737                                   NaN
# 5728                                   NaN
# 5721                                   NaN
# 5717                                   NaN
# 5716                                   NaN
# 5654                                   NaN
# 5256                                   NaN
# 5075                                   NaN
# 3601                                   NaN
# 3363                                   NaN
# 2507                      1962.08.30.b-pdf
# 2089                                   NaN
# 1594                                   NaN
# 1136  1925.06.15 Princess Royal Harbor.pdf
# 1115               1924.03.24.Sisargas.pdf
# 968                       1914.07.15.R.pdf
# 966                         1914.07.07.pdf
# 807                                    NaN
# 733                                    NaN
# 715               1898.09.19.a.R.Sully.pdf
# 578                                    NaN
# 372                                    NaN
# 358               1864.05.00.Mauritius.pdf
# 166                                    NaN

# %%
###in the Type Section after investigating, some consider boating a provoked attack, but 
##we don´t know how we will use the data so we will leave it like that
df['Type'] = df['Type'].str.replace(r"Boating|Boatomg", "Boat", regex =True)
df['Type'] = df['Type'].str.replace('Invalid|Questionable','Unknown')
#Sea disasters are unprovoked https://data.opendatasoft.com/explore/dataset/global-shark-attack%40public-us/information/
#But that database uses 5 categories so we will leave those 5
df['Type'].value_counts()
# Out:
# Unprovoked      4593
# Provoked         574
# Unknown          547
# Boat             340
# Sea Disaster     237
# Name: Type, dtype: int64

# %%
####Species####
df.rename(columns={'Species ': 'Species'}, inplace=True)
dic ={'\d*\sm\s':'' ,'\d\'' : '','\sto\s':'','\sm\s':'', ',':'',  '\d*m':'','[0-9]*.[0-9]':'','[0-9]':'','\.|\'' :'','"':'','\[|\]':''}
df['Species'].replace(dic, regex = True, inplace= True)
dic1 ={'involveent|invovleent':'involvement','confired':'confirmed'}
df['Species'].replace(dic1, regex = True, inplace= True)
df['Species']= df['Species'].str.strip()
df['Species'].value_counts()
# Out:
# shark                                                                   700
# White shark                                                             347
# Tiger shark                                                             181
# Bull shark                                                              112
# Shark involvement priordeath was not confirmed                          105
#                                                                        ...
# White shark or bronze whaler                                              1
# Shark involvement not confirmed injury ay be duea stingray                1
# Leon shark  feale                                                         1
# Dooley believed his Injury was caused by stingray (Dasyatidae faily)      1
# haerhead or bonnethed shark                                               1
# Name: Species, Length: 712, dtype: int64

# %%
####When we dont know the name we will call males John Doe and females Jane Doe
df['Name']= df['Name'].str.replace('female','Jane Doe')
df['Name']= df['Name'].str.replace(r'male|boy|men|fisherman|a young Scotsman|a native |crewman','John Doe',regex=True)
df['Name'].value_counts()
# Out:
# John Doe           580
# Jane Doe            97
# 2 John Does         18
# boat                14
# child               12
#                   ...
# Stuart Anderson      1
# Abdol Karmi          1
# Enrico & Noce        1
# Don M. Clark         1
# Mr. Bennett          1
# Name: Name, Length: 5220, dtype: int64

# %%
#### We will standarize the Sex column to have only M and F
df.rename(columns={'Sex ': 'Sex'}, inplace=True)
df['Sex'] = df['Sex'].str.replace('N', 'M')
df['Sex'] = df['Sex'].str.strip()
df['Sex'] = df['Sex'].fillna('Unknown')
df['Sex'] = df['Sex'].str.replace('lli', 'Unknown')
df['Sex'] = df['Sex'].str.replace('.', 'Unknown')
df['Sex'].value_counts()
# Out:
# M          5097
# F           637
# Unknown     561
# Name: Sex, dtype: int64

# %%
####Fatal Rellenamos cuando aparece Fatal en Injury y N cuando no aparece la palabra fatal
df['Fatal (Y/N)']= np.where(df['Injury'].str.contains('FATAL', flags=re.IGNORECASE, regex=True),  'Y', 'N')
df['Fatal (Y/N)'].value_counts()
# Out:
# N    4908
# Y    1387
# Name: Fatal (Y/N), dtype: int64

# %%
df['Country'].fillna('Unknown', inplace=True)
df['Country'] = df['Country'].str.strip().str.upper()

# %%
df.to_csv('attacks_new.csv', encoding = 'latin-1', sep=',')
